# %%
import tensorflow as tf
print(tf.__version__)

print("GPU доступно:", tf.test.is_gpu_available())

if tf.test.is_gpu_available():
    device_name = tf.test.gpu_device_name()

else:
    device_name = 'cpu:0'
    
print(device_name)
# Out:
# 2.3.1
# GPU доступно: False
# cpu:0

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def make_generator_network(
        num_hidden_layers=1,
        num_hidden_units=100,
        num_output_units=784):
    model = tf.keras.Sequential()
    for i in range(num_hidden_layers):
        model.add(
            tf.keras.layers.Dense(
                units=num_hidden_units, 
                use_bias=False)
            )
        model.add(tf.keras.layers.LeakyReLU())
        
    model.add(tf.keras.layers.Dense(
        units=num_output_units, activation='tanh'))
    return model

def make_discriminator_network(
        num_hidden_layers=1,
        num_hidden_units=100,
        num_output_units=1):
    model = tf.keras.Sequential()
    for i in range(num_hidden_layers):
        model.add(tf.keras.layers.Dense(units=num_hidden_units))
        model.add(tf.keras.layers.LeakyReLU())
        model.add(tf.keras.layers.Dropout(rate=0.5))
        
    model.add(
        tf.keras.layers.Dense(
            units=num_output_units, 
            activation=None)
        )
    return model

# %%
image_size = (28, 28)
z_size = 20
mode_z = 'uniform'  
gen_hidden_layers = 1
gen_hidden_size = 100
disc_hidden_layers = 1
disc_hidden_size = 100

tf.random.set_seed(1)

gen_model = make_generator_network(
    num_hidden_layers=gen_hidden_layers, 
    num_hidden_units=gen_hidden_size,
    num_output_units=np.prod(image_size))

gen_model.build(input_shape=(None, z_size))
gen_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               2000
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 784)               79184
# =================================================================
# Total params: 81,184
# Trainable params: 81,184
# Non-trainable params: 0
# _________________________________________________________________

# %%
disc_model = make_discriminator_network(
    num_hidden_layers=disc_hidden_layers,
    num_hidden_units=disc_hidden_size)

disc_model.build(input_shape=(None, np.prod(image_size)))
disc_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 100)               78500
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 100)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 78,601
# Trainable params: 78,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
mnist_bldr = tfds.builder('mnist')
mnist_bldr.download_and_prepare()
mnist = mnist_bldr.as_dataset(shuffle_files=False)

def preprocess(ex, mode='uniform'):
    image = ex['image']
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.reshape(image, [-1])
    image = image*2 - 1.0
    if mode == 'uniform':
        input_z = tf.random.uniform(
            shape=(z_size,), minval=-1.0, maxval=1.0)
    elif mode == 'normal':
        input_z = tf.random.normal(shape=(z_size,))
    return input_z, image



mnist_trainset = mnist['train']

print('Перед:  ')
example = next(iter(mnist_trainset))['image']
print('dtype: ', example.dtype, ' Min: {} Max: {}'.format(np.min(example), np.max(example)))

mnist_trainset = mnist_trainset.map(preprocess)

print('После:  ')
example = next(iter(mnist_trainset))[0]
print('dtype: ', example.dtype, ' Min: {} Max: {}'.format(np.min(example), np.max(example)))
# Out:
# Перед:
# dtype:  <dtype: 'uint8'>  Min: 0 Max: 255
# После:
# dtype:  <dtype: 'float32'>  Min: -0.8737728595733643 Max: 0.9460210800170898

# %%
mnist_trainset = mnist_trainset.batch(32, drop_remainder=True)
input_z, input_real = next(iter(mnist_trainset))
print('input-z -- форма:', input_z.shape)
print('input-real -- форма:', input_real.shape)

g_output = gen_model(input_z)
print('Выход G -- форма:', g_output.shape)

d_logits_real = disc_model(input_real)
d_logits_fake = disc_model(g_output)
print('Дискриминатор (настоящие) -- форма:', d_logits_real.shape)
print('Дискриминатор (фальшивые) -- форма:', d_logits_fake.shape)
# Out:
# input-z -- форма: (32, 20)
# input-real -- форма: (32, 784)
# Выход G -- форма: (32, 784)
# Дискриминатор (настоящие) -- форма: (32, 1)
# Дискриминатор (фальшивые) -- форма: (32, 1)

# %%
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=True)

g_labels_real = tf.ones_like(d_logits_fake)
g_loss = loss_fn(y_true=g_labels_real, y_pred=d_logits_fake)
print('Потеря генератора: {:.4f}'.format(g_loss))

d_labels_real = tf.ones_like(d_logits_real)
d_labels_fake = tf.zeros_like(d_logits_fake)

d_loss_real = loss_fn(y_true=d_labels_real, y_pred=d_logits_real)
d_loss_fake = loss_fn(y_true=d_labels_fake, y_pred=d_logits_fake)
print('Потеря дискриминатора: Настоящие {:.4f} Фальшивые {:.4f}'
      .format(d_loss_real.numpy(), d_loss_fake.numpy()))
# Out:
# Потеря генератора: 0.7355
# Потеря дискриминатора: Настоящие 1.5073 Фальшивые 0.6583

# %%
import time


num_epochs = 100
batch_size = 64
image_size = (28, 28)
z_size = 20
mode_z = 'uniform'
gen_hidden_layers = 1
gen_hidden_size = 100
disc_hidden_layers = 1
disc_hidden_size = 100

tf.random.set_seed(1)
np.random.seed(1)


if mode_z == 'uniform':
    fixed_z = tf.random.uniform(
        shape=(batch_size, z_size),
        minval=-1, maxval=1)
elif mode_z == 'normal':
    fixed_z = tf.random.normal(
        shape=(batch_size, z_size))


def create_samples(g_model, input_z):
    g_output = g_model(input_z, training=False)
    images = tf.reshape(g_output, (batch_size, *image_size))    
    return (images+1)/2.0

## Set-up the dataset
mnist_trainset = mnist['train']
mnist_trainset = mnist_trainset.map(
    lambda ex: preprocess(ex, mode=mode_z))

mnist_trainset = mnist_trainset.shuffle(10000)
mnist_trainset = mnist_trainset.batch(
    batch_size, drop_remainder=True)

## Set-up the model
with tf.device(device_name):
    gen_model = make_generator_network(
        num_hidden_layers=gen_hidden_layers, 
        num_hidden_units=gen_hidden_size,
        num_output_units=np.prod(image_size))
    gen_model.build(input_shape=(None, z_size))

    disc_model = make_discriminator_network(
        num_hidden_layers=disc_hidden_layers,
        num_hidden_units=disc_hidden_size)
    disc_model.build(input_shape=(None, np.prod(image_size)))

## Loss function and optimizers:
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=True)
g_optimizer = tf.keras.optimizers.Adam()
d_optimizer = tf.keras.optimizers.Adam()

all_losses = []
all_d_vals = []
epoch_samples = []

start_time = time.time()
for epoch in range(1, num_epochs+1):
    epoch_losses, epoch_d_vals = [], []
    for i,(input_z,input_real) in enumerate(mnist_trainset):
        
        ## Compute generator's loss
        with tf.GradientTape() as g_tape:
            g_output = gen_model(input_z)
            d_logits_fake = disc_model(g_output, training=True)
            labels_real = tf.ones_like(d_logits_fake)
            g_loss = loss_fn(y_true=labels_real, y_pred=d_logits_fake)
            
        g_grads = g_tape.gradient(g_loss, gen_model.trainable_variables)
        g_optimizer.apply_gradients(
            grads_and_vars=zip(g_grads, gen_model.trainable_variables))

        ## Compute discriminator's loss
        with tf.GradientTape() as d_tape:
            d_logits_real = disc_model(input_real, training=True)

            d_labels_real = tf.ones_like(d_logits_real)
            
            d_loss_real = loss_fn(
                y_true=d_labels_real, y_pred=d_logits_real)

            d_logits_fake = disc_model(g_output, training=True)
            d_labels_fake = tf.zeros_like(d_logits_fake)

            d_loss_fake = loss_fn(
                y_true=d_labels_fake, y_pred=d_logits_fake)

            d_loss = d_loss_real + d_loss_fake

        ## Compute the gradients of d_loss
        d_grads = d_tape.gradient(d_loss, disc_model.trainable_variables)
        
        ## Optimization: Apply the gradients
        d_optimizer.apply_gradients(
            grads_and_vars=zip(d_grads, disc_model.trainable_variables))
                           
        epoch_losses.append(
            (g_loss.numpy(), d_loss.numpy(), 
             d_loss_real.numpy(), d_loss_fake.numpy()))
        
        d_probs_real = tf.reduce_mean(tf.sigmoid(d_logits_real))
        d_probs_fake = tf.reduce_mean(tf.sigmoid(d_logits_fake))
        epoch_d_vals.append((d_probs_real.numpy(), d_probs_fake.numpy()))        
    all_losses.append(epoch_losses)
    all_d_vals.append(epoch_d_vals)
    print(
        'Epoch {:03d} | ET {:.2f} min | Avg Losses >>'
        ' G/D {:.4f}/{:.4f} [D-Real: {:.4f} D-Fake: {:.4f}]'
        .format(
            epoch, (time.time() - start_time)/60, 
            *list(np.mean(all_losses[-1], axis=0))))
    epoch_samples.append(
        create_samples(gen_model, fixed_z).numpy())
# Out:
# Epoch 001 | ET 0.53 min | Avg Losses >> G/D 2.8689/0.2889 [D-Real: 0.0333 D-Fake: 0.2556]
# Epoch 002 | ET 1.07 min | Avg Losses >> G/D 5.1842/0.3522 [D-Real: 0.1161 D-Fake: 0.2361]
# Epoch 003 | ET 1.62 min | Avg Losses >> G/D 3.1741/0.7055 [D-Real: 0.3164 D-Fake: 0.3891]
# Epoch 004 | ET 2.22 min | Avg Losses >> G/D 2.4890/0.7757 [D-Real: 0.3923 D-Fake: 0.3834]
# Epoch 005 | ET 2.83 min | Avg Losses >> G/D 2.0487/0.8413 [D-Real: 0.4568 D-Fake: 0.3845]
# Epoch 006 | ET 3.44 min | Avg Losses >> G/D 1.6989/0.9252 [D-Real: 0.5074 D-Fake: 0.4178]
# Epoch 007 | ET 4.05 min | Avg Losses >> G/D 1.6782/0.9926 [D-Real: 0.5282 D-Fake: 0.4645]
# Epoch 008 | ET 4.66 min | Avg Losses >> G/D 1.4398/0.9864 [D-Real: 0.5414 D-Fake: 0.4450]
# Epoch 009 | ET 5.26 min | Avg Losses >> G/D 1.6268/0.9860 [D-Real: 0.5300 D-Fake: 0.4561]
# Epoch 010 | ET 5.86 min | Avg Losses >> G/D 1.4034/1.0418 [D-Real: 0.5666 D-Fake: 0.4752]
# Epoch 011 | ET 6.48 min | Avg Losses >> G/D 1.2890/1.0940 [D-Real: 0.5832 D-Fake: 0.5108]
# Epoch 012 | ET 7.07 min | Avg Losses >> G/D 1.4014/1.0735 [D-Real: 0.5691 D-Fake: 0.5044]
# Epoch 013 | ET 7.35 min | Avg Losses >> G/D 1.2720/1.1293 [D-Real: 0.5877 D-Fake: 0.5416]
# Epoch 014 | ET 7.59 min | Avg Losses >> G/D 1.2050/1.1549 [D-Real: 0.6022 D-Fake: 0.5527]
# Epoch 015 | ET 7.83 min | Avg Losses >> G/D 1.1680/1.1751 [D-Real: 0.6106 D-Fake: 0.5645]
# Epoch 016 | ET 8.06 min | Avg Losses >> G/D 1.2581/1.1608 [D-Real: 0.5955 D-Fake: 0.5654]
# Epoch 017 | ET 8.29 min | Avg Losses >> G/D 1.2099/1.1436 [D-Real: 0.5982 D-Fake: 0.5454]
# Epoch 018 | ET 8.51 min | Avg Losses >> G/D 1.1462/1.1469 [D-Real: 0.5958 D-Fake: 0.5511]
# Epoch 019 | ET 8.73 min | Avg Losses >> G/D 1.1938/1.2162 [D-Real: 0.6118 D-Fake: 0.6044]
# Epoch 020 | ET 8.96 min | Avg Losses >> G/D 1.1724/1.1912 [D-Real: 0.6084 D-Fake: 0.5828]
# Epoch 021 | ET 9.17 min | Avg Losses >> G/D 1.0564/1.2163 [D-Real: 0.6236 D-Fake: 0.5927]
# Epoch 022 | ET 9.39 min | Avg Losses >> G/D 1.1056/1.2050 [D-Real: 0.6183 D-Fake: 0.5867]
# Epoch 023 | ET 9.59 min | Avg Losses >> G/D 1.1911/1.1950 [D-Real: 0.6042 D-Fake: 0.5908]
# Epoch 024 | ET 9.80 min | Avg Losses >> G/D 1.0565/1.2298 [D-Real: 0.6266 D-Fake: 0.6032]
# Epoch 025 | ET 10.02 min | Avg Losses >> G/D 1.0207/1.2262 [D-Real: 0.6282 D-Fake: 0.5981]
# Epoch 026 | ET 10.23 min | Avg Losses >> G/D 1.1036/1.2084 [D-Real: 0.6122 D-Fake: 0.5961]
# Epoch 027 | ET 10.45 min | Avg Losses >> G/D 1.1175/1.2223 [D-Real: 0.6177 D-Fake: 0.6045]
# Epoch 028 | ET 10.66 min | Avg Losses >> G/D 1.0281/1.2459 [D-Real: 0.6305 D-Fake: 0.6155]
# Epoch 029 | ET 10.87 min | Avg Losses >> G/D 1.0121/1.2532 [D-Real: 0.6326 D-Fake: 0.6206]
# Epoch 030 | ET 11.08 min | Avg Losses >> G/D 1.0145/1.2550 [D-Real: 0.6350 D-Fake: 0.6200]
# Epoch 031 | ET 11.29 min | Avg Losses >> G/D 1.0055/1.2660 [D-Real: 0.6364 D-Fake: 0.6296]
# Epoch 032 | ET 11.51 min | Avg Losses >> G/D 1.0104/1.2592 [D-Real: 0.6360 D-Fake: 0.6232]
# Epoch 033 | ET 11.72 min | Avg Losses >> G/D 1.0142/1.2601 [D-Real: 0.6369 D-Fake: 0.6232]
# Epoch 034 | ET 11.94 min | Avg Losses >> G/D 1.0041/1.2569 [D-Real: 0.6378 D-Fake: 0.6191]
# Epoch 035 | ET 12.15 min | Avg Losses >> G/D 1.0246/1.2655 [D-Real: 0.6363 D-Fake: 0.6292]
# Epoch 036 | ET 12.37 min | Avg Losses >> G/D 1.0048/1.2744 [D-Real: 0.6411 D-Fake: 0.6333]
# Epoch 037 | ET 12.58 min | Avg Losses >> G/D 0.9472/1.2896 [D-Real: 0.6480 D-Fake: 0.6416]
# Epoch 038 | ET 12.79 min | Avg Losses >> G/D 0.9756/1.2893 [D-Real: 0.6484 D-Fake: 0.6409]
# Epoch 039 | ET 13.01 min | Avg Losses >> G/D 0.9945/1.2860 [D-Real: 0.6463 D-Fake: 0.6397]
# Epoch 040 | ET 13.22 min | Avg Losses >> G/D 0.9680/1.2948 [D-Real: 0.6512 D-Fake: 0.6436]
# Epoch 041 | ET 13.44 min | Avg Losses >> G/D 0.9460/1.3032 [D-Real: 0.6534 D-Fake: 0.6498]
# Epoch 042 | ET 13.65 min | Avg Losses >> G/D 1.0321/1.2750 [D-Real: 0.6400 D-Fake: 0.6350]
# Epoch 043 | ET 13.87 min | Avg Losses >> G/D 1.0086/1.2707 [D-Real: 0.6398 D-Fake: 0.6309]
# Epoch 044 | ET 14.09 min | Avg Losses >> G/D 0.9290/1.2906 [D-Real: 0.6514 D-Fake: 0.6392]
# Epoch 045 | ET 14.31 min | Avg Losses >> G/D 0.9450/1.2915 [D-Real: 0.6493 D-Fake: 0.6422]
# Epoch 046 | ET 14.52 min | Avg Losses >> G/D 1.0113/1.2699 [D-Real: 0.6397 D-Fake: 0.6302]
# Epoch 047 | ET 14.73 min | Avg Losses >> G/D 0.9745/1.2685 [D-Real: 0.6413 D-Fake: 0.6272]
# Epoch 048 | ET 14.95 min | Avg Losses >> G/D 0.9446/1.2864 [D-Real: 0.6501 D-Fake: 0.6363]
# Epoch 049 | ET 15.16 min | Avg Losses >> G/D 0.9549/1.2888 [D-Real: 0.6465 D-Fake: 0.6423]
# Epoch 050 | ET 15.38 min | Avg Losses >> G/D 0.9674/1.2887 [D-Real: 0.6472 D-Fake: 0.6416]
# Epoch 051 | ET 15.59 min | Avg Losses >> G/D 0.9668/1.2939 [D-Real: 0.6476 D-Fake: 0.6463]
# Epoch 052 | ET 15.81 min | Avg Losses >> G/D 0.9243/1.3091 [D-Real: 0.6557 D-Fake: 0.6534]
# Epoch 053 | ET 16.02 min | Avg Losses >> G/D 0.9253/1.3068 [D-Real: 0.6554 D-Fake: 0.6514]
# Epoch 054 | ET 16.24 min | Avg Losses >> G/D 0.9474/1.3041 [D-Real: 0.6551 D-Fake: 0.6490]
# Epoch 055 | ET 16.46 min | Avg Losses >> G/D 0.9726/1.3029 [D-Real: 0.6506 D-Fake: 0.6523]
# Epoch 056 | ET 16.68 min | Avg Losses >> G/D 0.9297/1.3030 [D-Real: 0.6551 D-Fake: 0.6479]
# Epoch 057 | ET 16.90 min | Avg Losses >> G/D 0.9200/1.3048 [D-Real: 0.6568 D-Fake: 0.6480]
# Epoch 058 | ET 17.11 min | Avg Losses >> G/D 0.9675/1.2933 [D-Real: 0.6479 D-Fake: 0.6454]
# Epoch 059 | ET 17.33 min | Avg Losses >> G/D 0.9446/1.3058 [D-Real: 0.6559 D-Fake: 0.6499]
# Epoch 060 | ET 17.54 min | Avg Losses >> G/D 0.9140/1.3159 [D-Real: 0.6595 D-Fake: 0.6564]
# Epoch 061 | ET 17.75 min | Avg Losses >> G/D 0.9494/1.3059 [D-Real: 0.6547 D-Fake: 0.6512]
# Epoch 062 | ET 17.95 min | Avg Losses >> G/D 0.9249/1.3014 [D-Real: 0.6539 D-Fake: 0.6475]
# Epoch 063 | ET 18.14 min | Avg Losses >> G/D 0.9074/1.3140 [D-Real: 0.6600 D-Fake: 0.6539]
# Epoch 064 | ET 18.33 min | Avg Losses >> G/D 0.9413/1.3024 [D-Real: 0.6555 D-Fake: 0.6469]
# Epoch 065 | ET 18.53 min | Avg Losses >> G/D 0.9602/1.3006 [D-Real: 0.6531 D-Fake: 0.6475]
# Epoch 066 | ET 18.72 min | Avg Losses >> G/D 0.8974/1.3154 [D-Real: 0.6617 D-Fake: 0.6537]
# Epoch 067 | ET 18.92 min | Avg Losses >> G/D 0.9436/1.3062 [D-Real: 0.6560 D-Fake: 0.6502]
# Epoch 068 | ET 19.11 min | Avg Losses >> G/D 0.9506/1.2966 [D-Real: 0.6499 D-Fake: 0.6468]
# Epoch 069 | ET 19.31 min | Avg Losses >> G/D 0.9086/1.3069 [D-Real: 0.6574 D-Fake: 0.6495]
# Epoch 070 | ET 19.51 min | Avg Losses >> G/D 0.9498/1.2993 [D-Real: 0.6509 D-Fake: 0.6484]
# Epoch 071 | ET 19.70 min | Avg Losses >> G/D 0.9382/1.3064 [D-Real: 0.6550 D-Fake: 0.6514]
# Epoch 072 | ET 19.90 min | Avg Losses >> G/D 0.9390/1.3025 [D-Real: 0.6532 D-Fake: 0.6492]
# Epoch 073 | ET 20.09 min | Avg Losses >> G/D 0.9357/1.2956 [D-Real: 0.6530 D-Fake: 0.6425]
# Epoch 074 | ET 20.28 min | Avg Losses >> G/D 0.9154/1.3186 [D-Real: 0.6615 D-Fake: 0.6570]
# Epoch 075 | ET 20.48 min | Avg Losses >> G/D 0.9405/1.3063 [D-Real: 0.6562 D-Fake: 0.6501]
# Epoch 076 | ET 20.67 min | Avg Losses >> G/D 0.9098/1.3072 [D-Real: 0.6549 D-Fake: 0.6523]
# Epoch 077 | ET 20.87 min | Avg Losses >> G/D 0.9428/1.3061 [D-Real: 0.6548 D-Fake: 0.6512]
# Epoch 078 | ET 21.07 min | Avg Losses >> G/D 0.9748/1.3023 [D-Real: 0.6529 D-Fake: 0.6494]
# Epoch 079 | ET 21.27 min | Avg Losses >> G/D 0.8842/1.3205 [D-Real: 0.6636 D-Fake: 0.6568]
# Epoch 080 | ET 21.46 min | Avg Losses >> G/D 0.9003/1.3280 [D-Real: 0.6678 D-Fake: 0.6603]
# Epoch 081 | ET 21.66 min | Avg Losses >> G/D 0.9425/1.3062 [D-Real: 0.6537 D-Fake: 0.6526]
# Epoch 082 | ET 21.88 min | Avg Losses >> G/D 0.9095/1.3176 [D-Real: 0.6612 D-Fake: 0.6564]
# Epoch 083 | ET 22.18 min | Avg Losses >> G/D 0.9226/1.3157 [D-Real: 0.6598 D-Fake: 0.6560]
# Epoch 084 | ET 22.38 min | Avg Losses >> G/D 0.9228/1.3105 [D-Real: 0.6575 D-Fake: 0.6530]
# Epoch 085 | ET 22.60 min | Avg Losses >> G/D 0.9103/1.3142 [D-Real: 0.6605 D-Fake: 0.6537]
# Epoch 086 | ET 22.82 min | Avg Losses >> G/D 0.9110/1.3266 [D-Real: 0.6664 D-Fake: 0.6603]
# Epoch 087 | ET 23.05 min | Avg Losses >> G/D 0.8971/1.3127 [D-Real: 0.6595 D-Fake: 0.6532]
# Epoch 088 | ET 23.27 min | Avg Losses >> G/D 0.9083/1.3169 [D-Real: 0.6610 D-Fake: 0.6560]
# Epoch 089 | ET 23.48 min | Avg Losses >> G/D 0.9149/1.3083 [D-Real: 0.6562 D-Fake: 0.6520]
# Epoch 090 | ET 23.69 min | Avg Losses >> G/D 0.9049/1.3113 [D-Real: 0.6560 D-Fake: 0.6553]
# Epoch 091 | ET 23.89 min | Avg Losses >> G/D 0.9024/1.3265 [D-Real: 0.6662 D-Fake: 0.6603]
# Epoch 092 | ET 24.09 min | Avg Losses >> G/D 0.9195/1.3131 [D-Real: 0.6557 D-Fake: 0.6574]
# Epoch 093 | ET 24.31 min | Avg Losses >> G/D 0.8963/1.3202 [D-Real: 0.6632 D-Fake: 0.6571]
# Epoch 094 | ET 24.54 min | Avg Losses >> G/D 0.9549/1.3095 [D-Real: 0.6559 D-Fake: 0.6535]
# Epoch 095 | ET 24.76 min | Avg Losses >> G/D 0.9016/1.3207 [D-Real: 0.6618 D-Fake: 0.6590]
# Epoch 096 | ET 24.99 min | Avg Losses >> G/D 0.9105/1.3192 [D-Real: 0.6634 D-Fake: 0.6558]
# Epoch 097 | ET 25.21 min | Avg Losses >> G/D 0.9082/1.3116 [D-Real: 0.6583 D-Fake: 0.6533]
# Epoch 098 | ET 25.43 min | Avg Losses >> G/D 0.9030/1.3268 [D-Real: 0.6644 D-Fake: 0.6624]
# Epoch 099 | ET 25.65 min | Avg Losses >> G/D 0.9290/1.3100 [D-Real: 0.6574 D-Fake: 0.6526]
# Epoch 100 | ET 25.87 min | Avg Losses >> G/D 0.9247/1.3168 [D-Real: 0.6612 D-Fake: 0.6557]

# %%
import itertools


fig = plt.figure(figsize=(16, 6))

## Plotting the losses
ax = fig.add_subplot(1, 2, 1)
g_losses = [item[0] for item in itertools.chain(*all_losses)]
d_losses = [item[1]/2.0 for item in itertools.chain(*all_losses)]
plt.plot(g_losses, label='Generator loss', alpha=0.95)
plt.plot(d_losses, label='Discriminator loss', alpha=0.95)
plt.legend(fontsize=20)
ax.set_xlabel('Iteration', size=15)
ax.set_ylabel('Loss', size=15)

epochs = np.arange(1, 101)
epoch2iter = lambda e: e*len(all_losses[-1])
epoch_ticks = [1, 20, 40, 60, 80, 100]
newpos = [epoch2iter(e) for e in epoch_ticks]
ax2 = ax.twiny()
ax2.set_xticks(newpos)
ax2.set_xticklabels(epoch_ticks)
ax2.xaxis.set_ticks_position('bottom')
ax2.xaxis.set_label_position('bottom')
ax2.spines['bottom'].set_position(('outward', 60))
ax2.set_xlabel('Epoch', size=15)
ax2.set_xlim(ax.get_xlim())
ax.tick_params(axis='both', which='major', labelsize=15)
ax2.tick_params(axis='both', which='major', labelsize=15)

## Plotting the outputs of the discriminator
ax = fig.add_subplot(1, 2, 2)
d_vals_real = [item[0] for item in itertools.chain(*all_d_vals)]
d_vals_fake = [item[1] for item in itertools.chain(*all_d_vals)]
plt.plot(d_vals_real, alpha=0.75, label=r'Real: $D(\mathbf{x})$')
plt.plot(d_vals_fake, alpha=0.75, label=r'Fake: $D(G(\mathbf{z}))$')
plt.legend(fontsize=20)
ax.set_xlabel('Iteration', size=15)
ax.set_ylabel('Discriminator output', size=15)

ax2 = ax.twiny()
ax2.set_xticks(newpos)
ax2.set_xticklabels(epoch_ticks)
ax2.xaxis.set_ticks_position('bottom')
ax2.xaxis.set_label_position('bottom')
ax2.spines['bottom'].set_position(('outward', 60))
ax2.set_xlabel('Epoch', size=15)
ax2.set_xlim(ax.get_xlim())
ax.tick_params(axis='both', which='major', labelsize=15)
ax2.tick_params(axis='both', which='major', labelsize=15)

plt.show()

# %%
selected_epochs = [1, 2, 4, 10, 50, 100]
fig = plt.figure(figsize=(10, 14))
for i,e in enumerate(selected_epochs):
    for j in range(5):
        ax = fig.add_subplot(6, 5, i*5+j+1)
        ax.set_xticks([])
        ax.set_yticks([])
        if j == 0:
            ax.text(
                -0.06, 0.5, 'Эп {}'.format(e),
                rotation=90, size=18, color='red',
                horizontalalignment='right',
                verticalalignment='center', 
                transform=ax.transAxes)
        
        image = epoch_samples[e-1][j]
        ax.imshow(image, cmap='gray_r')
plt.show()
